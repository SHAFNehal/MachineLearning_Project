# %%
## Note: Do input Variable is used as we will decide upon it after preparing the data

# %%
# Modules
import tensorflow as tf

# %%
# Functions to Use for Neural Network of Different Architecture
def weight_variable(shape):
    init = tf.truncated_normal(shape, stddev=0.1)
    VareWeight=tf.Variable(init)                #As The weights will later be changed during Backpropagation
    return VarWeight

def bias_variable(shape):
    init = tf.constant(0.1, shape=shape)
    VarBias=tf.Variable(initial)
    return VarBias

def conv2d(x, W):
    Conv=tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
    return Conv

def max_pool_2x2(x):
    MaxPool= tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')
    return MaxPool

def Normalization(x,shape):
    Norm=tf.nn.local_response_normalization(x, depth_radius=5, bias=1.0, alpha=0.0001, beta=0.75, name=None)
    return Norm

# %%
# Place Holders (we need to put the size of the images here)
x = tf.placeholder("float", shape=[None,   ])
y = tf.placeholder("float", shape=[None,   ])

# %%
# Method 1
#------------------------------------------------------------------------------------------#
#                            Convolution Neural Network                                    #
#------------------------------------------------------------------------------------------#

#------------------------------------------------------------------------------------------#
#                          Layer 1 : Convolution Network                                   #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv1 = weight_variable([  ])
b_conv1 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv1 = tf.nn.relu(conv2d("Insert Image Here", W_conv1) + b_conv1)
# Max Pooling
h_pool1 = max_pool_2x2(h_conv1)

#------------------------------------------------------------------------------------------#
#                          Layer 2 : Convolution Network                                   #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv2 = weight_variable([         ])
b_conv2 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
# Max Pooling                         
h_pool2 = max_pool_2x2(h_conv2)

#------------------------------------------------------------------------------------------#
#                   Layer 3 : Fully Connected Neural Network                               #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_fc1 = weight_variable([    ])
b_fc1 = bias_variable([    ])

# Relu/Sigmoid/Softmax as per required
h_pool2_flat = tf.reshape(h_pool2, ["Reshaped size of the data you get as output in the previous layer"])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

#Drop out nodes from the network
keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

#------------------------------------------------------------------------------------------#
#                     Layer 4: Fully Connected Neural Network                              #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_fc2 = weight_variable([  ])
b_fc2 = bias_variable([ ])

# Output
y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

#------------------------------------------------------------------------------------------#
#                                    Optimization                                          #
#------------------------------------------------------------------------------------------#

#Optimization Operation
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

# %%
# Method 2
#------------------------------------------------------------------------------------------#
#                                      AlexNet                                             #
#------------------------------------------------------------------------------------------#

#------------------------------------------------------------------------------------------#
#             Layer 1 : Convolution Network + Max Pooling + Normalization                  #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv1 = weight_variable([  ])
b_conv1 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv1 = tf.nn.relu(conv2d("Insert Image Here", W_conv1) + b_conv1)
# Max Pooling
h_pool1 = max_pool_2x2(h_conv1)

# Normalization
Norm1=Normalization(h_pool1)

#------------------------------------------------------------------------------------------#
#               Layer 2 : Convolution Network + Max Pooling + Normalization                #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv2 = weight_variable([         ])
b_conv2 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv2 = tf.nn.relu(conv2d(Norm1, W_conv2) + b_conv2)
# Max Pooling                         
h_pool2 = max_pool_2x2(h_conv2)

# Normalization
Norm2=Normalization(h_pool2)


#------------------------------------------------------------------------------------------#
#                           Layer 3 : Convolution Network                                  #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv3 = weight_variable([         ])
b_conv3 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv3 = tf.nn.relu(conv2d(Norm2, W_conv3) + b_conv3)

#------------------------------------------------------------------------------------------#
#                           Layer 4 : Convolution Network                                  #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv4 = weight_variable([         ])
b_conv4 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv4 = tf.nn.relu(conv2d(h_conv3, W_conv4) + b_conv4)

#------------------------------------------------------------------------------------------#
#                     Layer 5 : Convolution Network + Max Pooling                          #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_conv5 = weight_variable([         ])
b_conv5 = bias_variable([  ])

# Relu/Sigmoid/Softmax as per required
h_conv5 = tf.nn.relu(conv2d(h_conv4, W_conv5) + b_conv5)
# Max Pooling                         
h_pool5 = max_pool_2x2(h_conv5)


#------------------------------------------------------------------------------------------#
#                   Layer 6 : Fully Connected Neural Network                               #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_fc1 = weight_variable([    ])
b_fc1 = bias_variable([    ])

# Relu/Sigmoid/Softmax as per required
h_pool2_flat = tf.reshape(h_pool5, ["Reshaped size of the data you get as output in the previous layer"])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

#Drop out nodes from the network
keep_prob1 = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob1)

#------------------------------------------------------------------------------------------#
#                   Layer 7 : Fully Connected Neural Network                               #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_fc2 = weight_variable([    ])
b_fc2 = bias_variable([    ])

# Relu/Sigmoid/Softmax as per required
h_pool3_flat = tf.reshape(h_fc1_drop, ["Reshaped size of the data you get as output in the previous layer"])
h_fc2 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc2) + b_fc2)

#Drop out nodes from the network
keep_prob2 = tf.placeholder("float")
h_fc2_drop = tf.nn.dropout(h_fc1, keep_prob2)


#------------------------------------------------------------------------------------------#
#                     Layer 8: Fully Connected Neural Network                              #
#------------------------------------------------------------------------------------------#

# Weight & Bias
W_fc3 = weight_variable([  ])
b_fc3 = bias_variable([ ])

# Output
y_conv=tf.nn.softmax(tf.matmul(h_fc2_drop, W_fc3) + b_fc3)

#------------------------------------------------------------------------------------------#
#                                    Optimization                                          #
#------------------------------------------------------------------------------------------#

#Optimization Operation
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

# %%
# Method 3
#------------------------------------------------------------------------------------------#
#                                    GoogleNet                                             #
#------------------------------------------------------------------------------------------#

# %%
# Run The Session

"Write The Code Later"
